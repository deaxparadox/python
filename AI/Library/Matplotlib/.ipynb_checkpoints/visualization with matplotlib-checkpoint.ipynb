# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
plt.style.use("classic")

# %%
fig = plt.figure()
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %% [markdown]
# **Saving Figures to File**

# %%
fig.savefig('my_figure.png')

# %% [markdown]
# *Check Image*

# %%
from IPython.display import Image

# %%
Image("my_figure.png")

# %%
# get image types support format
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# **MATLAB-style inteface**

# %%
# create a plot figure
plt.figure()

# create the first to two panels and set current axis 
plt.subplot(2,1,1)  # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2,1,2)
plt.plot(x, np.cos(x))

# %% [markdown]
# **Object oriented interface**

# %%
# First create a grid of plots 
# ax will be an array ot two Axis objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object 
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# **Simple Line Plots**

# %%
plt.style.use("seaborn-whitegrid")

# %%
fig = plt.figure()
ax = plt.axes()

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x))

# %%
# If we want to create a single figure with multiple lines, we simply call the plot function multiple times
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %% [markdown]
# **Ajusting the Plot: Line Colors and Styles**

# %%
# specify the color by name
plt.plot(x, np.sin(x-0), color='red')

# %%
# short color code (rgbcmyk)
plt.plot(x, np.sin(x-1), color='g')

# %%
# Grayscale between 0 and 1
plt.plot(x, np.sin(x-2), color='0.75')

# %%
# Hex code (RRGGBB from 00 and FF)
plt.plot(x, np.sin(x-3), color='#FFDD44')

# %%
# RGB tuple, valus 0 and 1
plt.plot(x, np.sin(x-4), color=(1.0, 0.2, 0.3))

# %%
# all HTML color names supported 
plt.plot(x, np.sin(x-5), color='chartreuse')

# %%
"""plot above charts together"""

# specify the color by name
plt.plot(x, np.sin(x-0), color='red')

# short color code (rgbcmyk)
plt.plot(x, np.sin(x-1), color='g')

# Grayscale between 0 and 1
plt.plot(x, np.sin(x-2), color='0.75')

# Hex code (RRGGBB from 00 and FF)
plt.plot(x, np.sin(x-3), color='#FFDD44')

# all HTML color names supported 
plt.plot(x, np.sin(x-5), color='chartreuse')

# %%
# you can adjust the line style using the linestyle keyword

plt.plot(x, x+0, linestyle='solid')
plt.plot(x, x+1, linestyle='dashed')
plt.plot(x, x+2, linestyle='dashdot')
plt.plot(x, x+3, linestyle='dotted')

# For short, you can use the following codes:
# short
plt.plot(x, x+4, linestyle='-')

# dashed
plt.plot(x, x+5, linestyle='--')

# dashdot
plt.plot(x, x+6, linestyle='-.')

# dotted
plt.plot(x, x+7, linestyle=':')

# %%
# these linestyle and color codes can be combined into a single nonkeyword argument
# to the plt.plot() function.

# solid green
plt.plot(x, x+0, '-g')

# dashed cyan
plt.plot(x, x+1, '--c')

# dashdot black 
plt.plot(x, x+2, '-.k')

# dotted red 
plt.plot(x, x+3, ':r')

# %% [markdown]
# **Adjusting the Plot: Axes Limits**

# %%
# to have have finer controls 
# The most Basic way to adjust axis limits is to use the plt.xlim() and plt.ylim() method

plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
# reverse


plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2)
# Out:
# (1.2, -1.2)

# %%
"""
- The plt.axis() method allows you to set the x and y limits with a 
single call, by passing a list that specifies [xmin, xmax, ymin, y,max]
"""

plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5])
# Out:
# (-1.0, 11.0, -1.5, 1.5)

# %%
"""automatically tighten the bounds around the current plot."""
plt.plot(x, np.sin(x))
plt.axis('tight')
# Out:
# (0.0, 10.0, -0.9999972954811321, 0.9999996994977832)

# %%
"""It allows even higher-evel specifications, such as ensuring an equal
aspect ratio so that on your screen, one unit in x is equal to one unit 
in y."""

plt.plot(x, np.sin(x))
plt.axis('equal')
# Out:
# (0.0, 10.0, -1.0, 1.0)

# %% [markdown]
# **Labeling Plots**

# %%
"""Titles and axis labels are th simplest such labels."""

plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)")
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
"""for creating legend use plt.legend()"""

plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend()

# %% [markdown]
# # Simple Scatter Plots

# %% [markdown]
# **Scatter Plots with plt.plot**

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black')

"""The third argument inthe function call is a character that represents the 
type of symbol used for the plotting."""

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker, label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8)
# Out:
# (0.0, 1.8)

# %%
# line (-), circle marker (o), black(k)
plt.plot(x, y, '-ok')

# %%
"""Additional keyword arguments to plt.plot specify a wide range of properties of the lines and markers"""

plt.plot(x, y, '-p', color='gray', markersize=15, linewidth=4, markerfacecolor='white',
        markeredgecolor='gray', markeredgewidth=2)
plt.ylim(-1.2, 1.2)
# Out:
# (-1.2, 1.2)

# %% [markdown]
# **Scatter Plots with plt.scatter**

# %%
"""second, more powerfull method of creating scatter plots is the plt.scatter() 
function"""

plt.scatter(x, y, marker='o')

# %%
"""The primary difference of plt.scatter from plt.plot is that it can be 
used to create scatter plots where the properties of each individual point
(size, face, color, edge color, etc.) can be indicidually controlled and mapped 
to data."""
# Out:
# 'The primary difference of plt.scatter from plt.plot is that it can be \nused to create scatter plots where the properties of each individual point\n(size, face, color, edge color, etc.) can be indicidually controlled and mapped \nto data.'

# %%
"""alpha keyword to adjust the transparency level."""

rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
plt.grid(False)

# show colorscale
plt.colorbar()
# Out:
# /tmp/ipykernel_506169/725855229.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T
plt.scatter(features[0], features[1], alpha=0.2, s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %% [markdown]
# # Visualizing Errors

# %% [markdown]
# **Basic Errorbars**

# %%
"""A basic errorbar can be created with a single Matplotlib function call."""

x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black', ecolor='lightgray', elinewidth=3, capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# **Continous Errors**

# %%
from sklearn.gaussian_process import GaussianProcess

# define the model and draw some data 
model = lambda x: x * np.sin(x)
xdata = np.array([1,3,5,6,8])
ydata = model(xdata)

# computethe Gaussian process fit
gp = GaussianProcess(corr='cubic', theta0=1e-2, theaL=1e-4, thetaY=1E-1, random_start=100)
fp.git(xdata[:, np.newaxis], ydata)

xfit = np.linspace(0, 10, 1000)
yfit, MSE = gp.predict(xfit[:, np.newaxis], eval_MSE=True)
dyfit = 2*np.sqrt(MSE)      # 2*sigma ~ 95% confidence region
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_506169/1531893935.py in <module>
# ----> 1 from sklearn.gaussian_process import GaussianProcess
#       2
#       3 # define the model and draw some data
#       4 model = lambda x: x * np.sin(x)
#       5 xdata = np.array([1,3,5,6,8])
#
# ImportError: cannot import name 'GaussianProcess' from 'sklearn.gaussian_process' (/home/creator/Documents/PythonDeveloper/pydev/lib/python3.9/site-packages/sklearn/gaussian_process/__init__.py)

# %%
# Visualize the result 
plt.plot(xdata, ydata, 'or')
plt.plot(xfit, yfit, '-', color='gray')
plt.fill_between(xfit, yfit-dyfit, yfit+dyfit, color='gray', alpha=0.2)
plt.xlim(0, 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_506169/3231421615.py in <module>
#       1 # Visualize the result
#       2 plt.plot(xdata, ydata, 'or')
# ----> 3 plt.plot(xfit, yfit, '-', color='gray')
#       4 plt.fill_between(xfit, yfit-dyfit, yfit+dyfit, color='gray', alpha=0.2)
#       5 plt.xlim(0, 10)
#
# NameError: name 'xfit' is not defined

# %% [markdown]
# # Density and Contour Plots

# %%
"""
- display three-dimensional data in two dimensiona using contours aor color-coded regions
- Theere are three Matplotlib functions that canb e helpfull for this task: 
    1. plt.contour
        - for contour plots
    2. plt.contoutf
        - for filled contour pots 
    3. plt.imshow
        - for showing images
"""
# Out:
# '\n- display three-dimensional data in two dimensiona using contours aor color-coded regions\n- Theere are three Matplotlib functions that canb e helpfull for this task: \n    1. plt.contour\n        - for contour plots\n    2. plt.contoutf\n        - for filled contour pots \n    3. plt.imshow\n        - for showing images\n'

# %% [markdown]
# **Visualizing a Three-Dimensional Function**

# %%
def f(x,y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
"""A contour plot can be created with the plt.contour function. 
- It takes three argument 
    1. a grid of x values
    2. a grid of y values
    3. a grid of z values
- The x and y values represent positions on the plot,
- and the z values, will be represented by the contour levels.
"""

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors='black')

# %%
"""you can color-code the lines by specifying a colormap with the cmap argument.
"""
plt.contour(X, Y, Z, 20, cmap='RdGy')

# %%
"""
- We can change this by switching to a filled contour plot using the 
plt.contourf() function, which uses largely the same syntax as plt.contour()

- plt.colorbar() command, which automatically creates an additional axis with 
labeled color information for the plot.
"""

plt.contourf(X, Y, Z, 20, cmap="RdGy")
plt.colorbar()
# Out:
# /tmp/ipykernel_506169/1923461984.py:10: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
"""use the plt.imshow() function, which interprets a two dimensional grid of data as an image."""

plt.imshow(Z, extent=[0,5,0,5], origin='lower', cmap='RdGy')
plt.colorbar()
plt.axis()
# Out:
# /tmp/ipykernel_506169/2133069434.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()
# (0.0, 5.0, 0.0, 5.0)

# %%
"""
- There are a few potential gotchas with imshow(), however:
    1. plt.imshow() doesn't accept an x and y grid, so you
    must manually specify the extent[xmin, xmax, ymin, ymax] of the 
    image on the plot
    2. plt.imshow() by default follows the standard image array 
    definition where the origin is in the upper left, not in the 
    lower left as in most contour plots. This must be cahnaged when
    showing gridded data.
    3. plt.imshow() will automatically adjust the axis aspect ratio
    to match the input data; you can change this by setting, for example,
    plt.axis(aspect='image') to make x and y units match.
"""

# %%
"""
- Combine contour plots and image plots
"""

contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)
plt.imshow(Z, extent=[0,5,0,5], origin='lower', cmap='RdGy', alpha=0.5)
plt.colorbar()
# Out:
# /tmp/ipykernel_506169/2323455027.py:8: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %% [markdown]
# **Historgrams, Binnings, and Density**

# %%
data = np.random.randn(1000)

# %%
plt.hist(data)
# Out:
# (array([  5.,  16.,  63., 160., 216., 274., 171.,  74.,  13.,   8.]),
#  array([-3.44991954, -2.77104989, -2.09218025, -1.4133106 , -0.73444095,
#         -0.05557131,  0.62329834,  1.30216799,  1.98103763,  2.65990728,
#          3.33877693]),
#  <BarContainer object of 10 artists>)

# %%
"""hist() function has many options to tune both the 
calculation and the display"""

"""convert 'normed=True' to 'density=True' """

plt.hist(data, bins=30, density=True, alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none')
# Out:
# (array([0.00883822, 0.00883822, 0.00441911, 0.        , 0.03093377,
#         0.03977199, 0.0839631 , 0.11489687, 0.07954399, 0.18118353,
#         0.20769819, 0.31817596, 0.36236706, 0.29608041, 0.29608041,
#         0.40213906, 0.45516838, 0.35352884, 0.32259507, 0.23863197,
#         0.19444086, 0.17234531, 0.11047776, 0.04419111, 0.02209555,
#         0.02209555, 0.01325733, 0.02209555, 0.00883822, 0.00441911]),
#  array([-3.44991954, -3.22362966, -2.99733978, -2.77104989, -2.54476001,
#         -2.31847013, -2.09218025, -1.86589037, -1.63960048, -1.4133106 ,
#         -1.18702072, -0.96073084, -0.73444095, -0.50815107, -0.28186119,
#         -0.05557131,  0.17071858,  0.39700846,  0.62329834,  0.84958822,
#          1.0758781 ,  1.30216799,  1.52845787,  1.75474775,  1.98103763,
#          2.20732752,  2.4336174 ,  2.65990728,  2.88619716,  3.11248704,
#          3.33877693]),
#  [<matplotlib.patches.Polygon at 0x7f03caf257f0>])

# %%
"""The plt.hist docstring has more information on other customization options available"""

x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, density=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)

# plt.savefig('histogram.png')
# Out:
# (array([0.0031194 , 0.0031194 , 0.0062388 , 0.01559701, 0.02495521,
#         0.02183581, 0.03743282, 0.03431342, 0.06550744, 0.06862684,
#         0.10605966, 0.10917906, 0.12477607, 0.13725368, 0.14973129,
#         0.1778059 , 0.19340291, 0.20899992, 0.18716411, 0.19340291,
#         0.18716411, 0.19652231, 0.1684477 , 0.11229846, 0.15285069,
#         0.09670146, 0.07486564, 0.06238804, 0.05302983, 0.04679103,
#         0.02495521, 0.02807462, 0.01871641, 0.01871641, 0.        ,
#         0.0031194 , 0.        , 0.0031194 , 0.        , 0.0031194 ]),
#  array([-2.98765611, -2.66708182, -2.34650754, -2.02593325, -1.70535897,
#         -1.38478468, -1.06421039, -0.74363611, -0.42306182, -0.10248754,
#          0.21808675,  0.53866103,  0.85923532,  1.1798096 ,  1.50038389,
#          1.82095817,  2.14153246,  2.46210674,  2.78268103,  3.10325531,
#          3.4238296 ,  3.74440388,  4.06497817,  4.38555245,  4.70612674,
#          5.02670102,  5.34727531,  5.66784959,  5.98842388,  6.30899816,
#          6.62957245,  6.95014674,  7.27072102,  7.59129531,  7.91186959,
#          8.23244388,  8.55301816,  8.87359245,  9.19416673,  9.51474102,
#          9.8353153 ]),
#  [<matplotlib.patches.Polygon at 0x7f03cae8f910>])

# %%
"""the np.histogram() function is available."""

counts, bin_edges = np.histogram(data, bins=5)
print(counts)
# Out:
# [ 21 223 490 245  21]

# %% [markdown]
# **Two-Dimensional Historgrams and Binnings**

# %%
"""We can also crate historgrams in two dimensions by dividing points among two-dimensional bins."""
mean = [0,0]
cov = [[1,1], [1,2]]
x,y = np.random.multivariate_normal(mean, cov, 10000).T

# %% [markdown]
# *plt.hist2d: Two-dimenional histogram*

# %%
"""a two dimensional histgram to use Matplotlib's plt.hist2d function"""

plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')
# Out:
# /tmp/ipykernel_506169/797746185.py:3: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.hist2d(x, y, bins=30, cmap='Blues')
# /tmp/ipykernel_506169/797746185.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cb = plt.colorbar()

# %%
'''plt.hist has a counterpart in np.histogram, plt.hist2d has a counterpart in np.histogram2d'''

counts, xedges, yedges = np.histogram2d(x, y, bins=30)

# %%
"""For the generalization of this histogram binning in dimensions higher than two, 
see the np.histogramdd function"""
# Out:
# 'For the generalization of this histogram binning in dimensions higher than two, \nsee the np.histogramdd function'

# %% [markdown]
# **plt.hexbin: Hexagonal binnigs**

# %%
"""A two-dimensional histogram with plt.hexbin"""

plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar(label='count in bin')
# Out:
# /tmp/ipykernel_506169/1095560785.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cb = plt.colorbar(label='count in bin')

# %% [markdown]
# *Kernel density estimation*

# %%
"""A KERNEL DENSITY REPRESENTATION OF A DISTRIBUTION

- Another common method of evaluating densities in multiple dimensions is kernel-density-estimation (KDE)

- One extremely equick and simple KDE implementation exists in the scipy.stats package.
"""

from scipy.stats import gaussian_kde

# fit an array of size [Ndim, Nsamples]
data = np.vstack([x, y])
kde = gaussian_kde(data)

# evaluate on a regular gride
xgrid = np.linspace(-3.5, 3.5, 40)
ygrid = np.linspace(-6, 6, 40)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
Z = kde.evaluate(np.vstack([Xgrid.ravel(), Ygrid.ravel()]))

# Plot the result as an image
plt.imshow(Z.reshape(Xgrid.shape), origin='lower', aspect='auto', extent=[-3.5, 3.5, -6, 6], cmap='Blues')
cb = plt.colorbar()
cb.set_label('density')
# Out:
# /tmp/ipykernel_506169/3666995154.py:22: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cb = plt.colorbar()

# %% [markdown]
# # Customizing Plot Legends

# %%
"""
The simple legendt can be created with the plt.legend() command, 
which automatically creates a legend for any labeled plot elements.
"""

plt.style.use('classic')

x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend()

"""A default plot legend"""
# Out:
# 'A default plot legend'

# %%
'''A customized plot legend'''

"""specify the location and turn of the frame for legend"""
ax.legend(loc='upper left', frameon=False)
fig

# %%
'''A two column legend plots'''
ax.legend(frameon=False, loc='lower center', ncol=2)
fig

# %%
"""A fancy plot legend"""

ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig

# %% [markdown]
# # Choosing Elements for the legend

# %%
"""
- we can fine tune which elements and labels appear in the legend by 
using the object returned by plot commands.

- The plot.plot() command is able to create multiple lines at one, and returns 
a list of created line instances

- Pasing any of these to plt.legend() will tell it which to identify along with the labels 
we'd like to specify.
"""

y = np.sin(x[:, np.newaxis] + np.pi * np.arange(0, 2, 0.5))
lines  = plt.plot(x,y)

# lines is a list of plt.Line2D instances
plt.legend(lines[:2], ['first', 'second'])

"""Customization of legend elements"""
# Out:
# 'Customization of legend elements'

# %%
plt.plot(x, y[:, 0], label='first')
plt.plot(x, y[:, 1], label='second')
plt.plot(x, y[:, 2])
plt.legend(framealpha=1, frameon=True)

# alternating method for customizing legend elements
